# %% [markdown]
# <a href="https://colab.research.google.com/github/bhadreshpsavani/HuggingfaceModelTraining/blob/main/SQUAD_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Installation:

# %%
# !git clone https://github.com/huggingface/transformers.git
# %cd transformers
# !pip install .
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 75456, done.
# remote: Counting objects: 100% (853/853), done.
# remote: Compressing objects: 100% (397/397), done.
# remote: Total 75456 (delta 462), reused 734 (delta 414), pack-reused 74603
# Receiving objects: 100% (75456/75456), 59.02 MiB | 30.17 MiB/s, done.
# Resolving deltas: 100% (53620/53620), done.
# /content/transformers
# Processing /content/transformers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 3.3MB 31.7MB/s
# ...
#      |████████████████████████████████| 901kB 50.4MB/s
# ...
#   Created wheel for transformers: filename=transformers-4.8.0.dev0-cp37-none-any.whl size=2474626 sha256=333d2459147c131bbf583dd0f053e8829f77e9f848c1831043719df4c91e7de6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sdlj9u5r/wheels/23/19/dd/2561a4e47240cf6b307729d58e56f8077dd0c698f5992216cf
# ...

# %%
# !pip install -q -r ./examples/pytorch/question-answering/requirements.txt
# %cd ..
# Out:
#      |████████████████████████████████| 245kB 30.3MB/s
#      |████████████████████████████████| 122kB 50.1MB/s
#      |████████████████████████████████| 245kB 46.8MB/s
# /content

# %% [markdown]
# ## Training

# %%
# !python transformers/examples/pytorch/question-answering/run_qa.py \
--model_name_or_path distilbert-base-uncased \
--dataset_name squad \
--do_train \
--do_eval \
--learning_rate 3e-5 \
--max_seq_length 384 \
--doc_stride 128 \
--output_dir /tmp/debug_squad/ \
--per_device_eval_batch_size 8   \
--per_device_train_batch_size 8   \
--evaluation_strategy "epoch" \
--save_strategy "no" \
--overwrite_output \
# Out:
# Streaming output truncated to the last 5000 lines.
#  51% 684/1348 [01:11<01:09,  9.53it/s]
#  51% 685/1348 [01:11<01:09,  9.59it/s]
#  51% 686/1348 [01:11<01:08,  9.60it/s]
#  51% 687/1348 [01:11<01:08,  9.63it/s]
#  51% 688/1348 [01:11<01:08,  9.58it/s]
#  51% 689/1348 [01:11<01:09,  9.52it/s]
#  51% 690/1348 [01:11<01:08,  9.56it/s]
#  51% 691/1348 [01:12<01:08,  9.58it/s]
#  51% 692/1348 [01:12<01:08,  9.57it/s]
#  51% 693/1348 [01:12<01:08,  9.61it/s]
#  51% 694/1348 [01:12<01:08,  9.61it/s]
#  52% 695/1348 [01:12<01:08,  9.51it/s]
#  52% 696/1348 [01:12<01:08,  9.50it/s]
#  52% 697/1348 [01:12<01:08,  9.50it/s]
#  52% 698/1348 [01:12<01:08,  9.53it/s]
#  52% 699/1348 [01:12<01:07,  9.60it/s]
#  52% 700/1348 [01:12<01:07,  9.62it/s]
#  52% 701/1348 [01:13<01:07,  9.54it/s]
#  52% 702/1348 [01:13<01:08,  9.47it/s]
#  52% 703/1348 [01:13<01:07,  9.51it/s]
#  52% 704/1348 [01:13<01:07,  9.55it/s]
#  52% 705/1348 [01:13<01:07,  9.58it/s]
#  52% 706/1348 [01:13<01:07,  9.54it/s]
# ...
